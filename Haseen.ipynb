# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore", UserWarning)

# %%
import os
import sys
import re
import time
import html
import warnings
from datetime import datetime
from typing import List, Tuple, Optional

import pandas as pd
import pyodbc
from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

try:
    import winsound
except ImportError:
    winsound = None

warnings.filterwarnings("ignore", category=UserWarning)

# ----------------------------- #
# --------- CONFIGURE --------- #
# ----------------------------- #

DB_STRUCTURE_PATH = r"C:\Users\IN10052060\Desktop\Python\SqlDBStructure.xlsx"
EXCEL_SHEET_NAME = "Medicare"

SQL_FOLDER = r"C:\Users\IN10052060\Downloads\Query"
OUTPUT_DIR = r"C:\Users\IN10052060\Downloads\Data"

DEFAULT_TIMEOUT_SECONDS = 120
ENABLE_ODBC_ENCRYPTION = False
DB_PAUSE_SECONDS = 0.20

# ----------------------------- #
# ---------- HELPERS ---------- #
# ----------------------------- #

def ensure_dir(path: str):
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)

def safe_strip(val):
    if val is None:
        return None
    return str(val).strip()

def read_db_targets_from_excel(xlsx_path: str, sheet_name: str) -> pd.DataFrame:
    wb = load_workbook(xlsx_path, data_only=True)
    ws = wb[sheet_name]

    targets = []
    for r in range(2, ws.max_row + 1):
        database = safe_strip(ws.cell(row=r, column=2).value)
        server   = safe_strip(ws.cell(row=r, column=3).value)

        if database and server:
            targets.append((database, server))

    df = pd.DataFrame(targets, columns=["Database", "Server"])
    df.drop_duplicates(inplace=True)
    return df

def read_sql_file(path: str) -> str:
    with open(path, "r", encoding="utf-8", errors="ignore") as f:
        return f.read()

def sanitize_query(sql_text: str) -> str:
    lines = [l for l in sql_text.splitlines() if l.strip().upper() != "GO"]
    text = "\n".join(lines)
    text = html.unescape(text)

    if not text.upper().startswith("SET NOCOUNT ON"):
        text = "SET NOCOUNT ON;\n" + text

    return text

def clean_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    if df is None or df.empty:
        return df

    df_cleaned = df.copy()

    # fix duplicate column names
    seen = {}
    new_cols = []
    for c in df_cleaned.columns:
        c = str(c).strip()
        if c in seen:
            seen[c] += 1
            new_cols.append(f"{c}.{seen[c]}")
        else:
            seen[c] = 0
            new_cols.append(c)
    df_cleaned.columns = new_cols

    return df_cleaned

def pick_best_odbc_driver() -> str:
    drivers = pyodbc.drivers()
    for cand in ("ODBC Driver 18 for SQL Server", "ODBC Driver 17 for SQL Server"):
        if cand in drivers:
            return cand
    return "SQL Server"

# ----------------------------- #
# -------- FETCH DATA --------- #
# ----------------------------- #

def fetch_data(database, server, query):

    start = datetime.now()
    conn = None

    try:
        driver = pick_best_odbc_driver()

        conn_str = (
            f"Driver={{{driver}}};"
            f"Server={server};"
            f"Database={database};"
            "Trusted_Connection=Yes;"
        )

        print(f"Connecting to {database} @ {server}")

        # ✅ IMPORTANT FIX
        conn = pyodbc.connect(conn_str, autocommit=False)
        cur = conn.cursor()

        # ✅ SSMS-like behavior
        session_settings = """
        SET NOCOUNT ON;
        SET ANSI_NULLS ON;
        SET QUOTED_IDENTIFIER ON;
        SET ARITHABORT ON;
        SET ANSI_WARNINGS ON;
        """

        cur.execute(session_settings + query)

        # ✅ FIX: FETCH FINAL RESULT SET
        final_rows = []
        final_columns = None

        while True:
            if cur.description:
                final_columns = [col[0] for col in cur.description]
                final_rows = cur.fetchall()   # overwrite → last result wins

            if not cur.nextset():
                break

        duration = (datetime.now() - start).total_seconds()

        if not final_columns:
            return pd.DataFrame(), 0, duration, "Success"

        df = pd.DataFrame.from_records(final_rows, columns=final_columns)

        print(f"RAW ROWS: {len(df)}")

        df_cleaned = clean_dataframe(df)

        print(f"FINAL ROWS: {len(df_cleaned)}")

        return df_cleaned, len(df_cleaned), duration, "Success"

    except Exception as e:
        duration = (datetime.now() - start).total_seconds()
        return None, 0, duration, str(e)

    finally:
        if conn:
            conn.close()

# ----------------------------- #
# ------------ MAIN ----------- #
# ----------------------------- #

def main():

    ensure_dir(OUTPUT_DIR)

    df_targets = read_db_targets_from_excel(DB_STRUCTURE_PATH, EXCEL_SHEET_NAME)
    servers_grouped = df_targets.groupby("Server")

    sql_files = [f for f in os.listdir(SQL_FOLDER) if f.endswith((".sql", ".txt"))]

    for sql_file in sql_files:

        query = sanitize_query(read_sql_file(os.path.join(SQL_FOLDER, sql_file)))

        for server, group in servers_grouped:

            print(f"\nProcessing Server: {server}")

            wb = Workbook()
            ws = wb.active
            ws.title = "Data"

            first = True

            for _, row in group.iterrows():
                db = row["Database"]

                df, rc, dur, status = fetch_data(db, server, query)

                if status == "Success" and df is not None:

                    if first:
                        for r in dataframe_to_rows(df, index=False, header=True):
                            ws.append(r)
                        first = False
                    else:
                        for r in dataframe_to_rows(df, index=False, header=False):
                            ws.append(r)

                time.sleep(DB_PAUSE_SECONDS)

            output = os.path.join(
                OUTPUT_DIR,
                f"{sql_file}_{server.replace(':','_')}.xlsx"
            )

            wb.save(output)
            print(f"Saved: {output}")

    if winsound:
        winsound.Beep(1000, 500)

    print("DONE")

if __name__ == "__main__":
    main()
# Out:
# Processing Server: AHS-TRAN10.accretivehealth.local
# Connecting to TranASIN @ AHS-TRAN10.accretivehealth.local
# RAW ROWS: 301
# FINAL ROWS: 301
# Connecting to TranCLIN @ AHS-TRAN10.accretivehealth.local
# RAW ROWS: 1940
# FINAL ROWS: 1940
# Connecting to TranECIN @ AHS-TRAN10.accretivehealth.local
# RAW ROWS: 151
# FINAL ROWS: 151
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN10.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN11.accretivehealth.local
# Connecting to TranNRIN @ AHS-TRAN11.accretivehealth.local
# RAW ROWS: 448
# FINAL ROWS: 448
# Connecting to TranVOIN @ AHS-TRAN11.accretivehealth.local
# RAW ROWS: 336
# FINAL ROWS: 336
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN11.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN12.accretivehealth.local
# Connecting to TranBYFL @ AHS-TRAN12.accretivehealth.local
# RAW ROWS: 4765
# FINAL ROWS: 4765
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN12.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN14.accretivehealth.local
# Connecting to TranEKWI @ AHS-TRAN14.accretivehealth.local
# RAW ROWS: 36123
# FINAL ROWS: 36123
# Connecting to TranEOWI @ AHS-TRAN14.accretivehealth.local
# RAW ROWS: 6830
# FINAL ROWS: 6830
# Connecting to TranESWI @ AHS-TRAN14.accretivehealth.local
# RAW ROWS: 254
# FINAL ROWS: 254
# Connecting to TranCHWI @ AHS-TRAN14.accretivehealth.local
# RAW ROWS: 4246
# FINAL ROWS: 4246
# Connecting to TranEEWI @ AHS-TRAN14.accretivehealth.local
# RAW ROWS: 16699
# FINAL ROWS: 16699
# Connecting to TranMHWI @ AHS-TRAN14.accretivehealth.local
# RAW ROWS: 6614
# FINAL ROWS: 6614
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN14.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN15.accretivehealth.local
# Connecting to TranBHTN @ AHS-TRAN15.accretivehealth.local
# RAW ROWS: 10709
# FINAL ROWS: 10709
# Connecting to TranMTTN @ AHS-TRAN15.accretivehealth.local
# RAW ROWS: 12750
# FINAL ROWS: 12750
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN15.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN16.accretivehealth.local
# Connecting to TranRPTN @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 7343
# FINAL ROWS: 7343
# Connecting to TranJBKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 35
# FINAL ROWS: 35
# Connecting to TranMHKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 2469
# FINAL ROWS: 2469
# Connecting to TranRHKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 537
# FINAL ROWS: 537
# Connecting to TranSTKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 1747
# FINAL ROWS: 1747
# Connecting to TranVFKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 7708
# FINAL ROWS: 7708
# Connecting to TranVJKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 4918
# FINAL ROWS: 4918
# Connecting to TranVWKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 7
# FINAL ROWS: 7
# Connecting to TranWHKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 492
# FINAL ROWS: 492
# Connecting to TranJAKS @ AHS-TRAN16.accretivehealth.local
# RAW ROWS: 0
# FINAL ROWS: 0
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN16.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN18.accretivehealth.local
# Connecting to TranBAOK @ AHS-TRAN18.accretivehealth.local
# RAW ROWS: 1580
# FINAL ROWS: 1580
# Connecting to TranJKOK @ AHS-TRAN18.accretivehealth.local
# RAW ROWS: 173
# FINAL ROWS: 173
# Connecting to TranJPOK @ AHS-TRAN18.accretivehealth.local
# RAW ROWS: 6808
# FINAL ROWS: 6808
# Connecting to TranMCOK @ AHS-TRAN18.accretivehealth.local
# RAW ROWS: 10420
# FINAL ROWS: 10420
# Connecting to TranNHOK @ AHS-TRAN18.accretivehealth.local
# RAW ROWS: 421
# FINAL ROWS: 421
# Connecting to TranOHOK @ AHS-TRAN18.accretivehealth.local
# RAW ROWS: 1439
# FINAL ROWS: 1439
# Connecting to TranSPOK @ AHS-TRAN18.accretivehealth.local
# RAW ROWS: 1490
# FINAL ROWS: 1490
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN18.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN19.accretivehealth.local
# Connecting to TranSTTN @ AHS-TRAN19.accretivehealth.local
# RAW ROWS: 7705
# FINAL ROWS: 7705
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN19.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN20.accretivehealth.local
# Connecting to TranSCFL @ AHS-TRAN20.accretivehealth.local
# RAW ROWS: 6032
# FINAL ROWS: 6032
# Connecting to TranSLFL @ AHS-TRAN20.accretivehealth.local
# RAW ROWS: 10840
# FINAL ROWS: 10840
# Connecting to TranSVFL @ AHS-TRAN20.accretivehealth.local
# RAW ROWS: 19326
# FINAL ROWS: 19326
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN20.accretivehealth.local.xlsx
#
# Processing Server: AHS-TRAN40.accretivehealth.local
# Connecting to TranDCNT @ AHS-TRAN40.accretivehealth.local
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_AHS-TRAN40.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN23.accretivehealth.local
# Connecting to TranEDTX @ ALPTRAN23.accretivehealth.local
# RAW ROWS: 2053
# FINAL ROWS: 2053
# Connecting to TranHLTX @ ALPTRAN23.accretivehealth.local
# RAW ROWS: 2578
# FINAL ROWS: 2578
# Connecting to TranHMTX @ ALPTRAN23.accretivehealth.local
# RAW ROWS: 8106
# FINAL ROWS: 8106
# Connecting to TranMCTX @ ALPTRAN23.accretivehealth.local
# RAW ROWS: 7423
# FINAL ROWS: 7423
# Connecting to TranSNTX @ ALPTRAN23.accretivehealth.local
# RAW ROWS: 2586
# FINAL ROWS: 2586
# Connecting to TranSSTX @ ALPTRAN23.accretivehealth.local
# RAW ROWS: 740
# FINAL ROWS: 740
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN23.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN24.accretivehealth.local
# Connecting to TranDCTX @ ALPTRAN24.accretivehealth.local
# RAW ROWS: 591
# FINAL ROWS: 591
# Connecting to TranDSTX @ ALPTRAN24.accretivehealth.local
# RAW ROWS: 6527
# FINAL ROWS: 6527
# Connecting to TranWMTX @ ALPTRAN24.accretivehealth.local
# RAW ROWS: 4028
# FINAL ROWS: 4028
# Connecting to TranPNTX @ ALPTRAN24.accretivehealth.local
# RAW ROWS: 6728
# FINAL ROWS: 6728
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN24.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN25.accretivehealth.local
# Connecting to TranSTIN @ ALPTRAN25.accretivehealth.local
# RAW ROWS: 106
# FINAL ROWS: 106
# Connecting to TranSVIN @ ALPTRAN25.accretivehealth.local
# RAW ROWS: 10824
# FINAL ROWS: 10824
# Connecting to TranVAIN @ ALPTRAN25.accretivehealth.local
# RAW ROWS: 6170
# FINAL ROWS: 6170
# Connecting to TranVCIN @ ALPTRAN25.accretivehealth.local
# RAW ROWS: 1358
# FINAL ROWS: 1358
# Connecting to TranVFIN @ ALPTRAN25.accretivehealth.local
# RAW ROWS: 934
# FINAL ROWS: 934
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN25.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN26.accretivehealth.local
# Connecting to TranVHIN @ ALPTRAN26.accretivehealth.local
# RAW ROWS: 449
# FINAL ROWS: 449
# Connecting to TranVJIN @ ALPTRAN26.accretivehealth.local
# RAW ROWS: 3093
# FINAL ROWS: 3093
# Connecting to TranVKIN @ ALPTRAN26.accretivehealth.local
# RAW ROWS: 5500
# FINAL ROWS: 5500
# Connecting to TranVMIN @ ALPTRAN26.accretivehealth.local
# RAW ROWS: 1280
# FINAL ROWS: 1280
# Connecting to TranVRIN @ ALPTRAN26.accretivehealth.local
# RAW ROWS: 2280
# FINAL ROWS: 2280
# Connecting to TranVSIN @ ALPTRAN26.accretivehealth.local
# RAW ROWS: 1843
# FINAL ROWS: 1843
# Connecting to TranVWIN @ ALPTRAN26.accretivehealth.local
# RAW ROWS: 2243
# FINAL ROWS: 2243
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN26.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN27.accretivehealth.local
# Connecting to TranPHTX @ ALPTRAN27.accretivehealth.local
# RAW ROWS: 8
# FINAL ROWS: 8
# Connecting to TranRHTN @ ALPTRAN27.accretivehealth.local
# RAW ROWS: 1216
# FINAL ROWS: 1216
# Connecting to TranSDTN @ ALPTRAN27.accretivehealth.local
# RAW ROWS: 1907
# FINAL ROWS: 1907
# Connecting to TranTHTN @ ALPTRAN27.accretivehealth.local
# RAW ROWS: 3872
# FINAL ROWS: 3872
# Connecting to TranEMFL @ ALPTRAN27.accretivehealth.local
# RAW ROWS: 1416
# FINAL ROWS: 1416
# Connecting to TranGCFL @ ALPTRAN27.accretivehealth.local
# RAW ROWS: 1208
# FINAL ROWS: 1208
# Connecting to TranSHFL @ ALPTRAN27.accretivehealth.local
# RAW ROWS: 23172
# FINAL ROWS: 23172
# Connecting to TranHKTN @ ALPTRAN27.accretivehealth.local
# RAW ROWS: 71
# FINAL ROWS: 71
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN27.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN28.accretivehealth.local
# Connecting to TranASWI @ ALPTRAN28.accretivehealth.local
# RAW ROWS: 53786
# FINAL ROWS: 53786
# Connecting to TranEMWI @ ALPTRAN28.accretivehealth.local
# RAW ROWS: 4394
# FINAL ROWS: 4394
# Connecting to TranFNWI @ ALPTRAN28.accretivehealth.local
# RAW ROWS: 5638
# FINAL ROWS: 5638
# Connecting to TranMWWI @ ALPTRAN28.accretivehealth.local
# RAW ROWS: 820
# FINAL ROWS: 820
# Connecting to TranSFWI @ ALPTRAN28.accretivehealth.local
# RAW ROWS: 11928
# FINAL ROWS: 11928
# Connecting to TranSJWI @ ALPTRAN28.accretivehealth.local
# RAW ROWS: 25260
# FINAL ROWS: 25260
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN28.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN29.accretivehealth.local
# Connecting to TranSWIN @ ALPTRAN29.accretivehealth.local
# RAW ROWS: 762
# FINAL ROWS: 762
# Connecting to TranVEIN @ ALPTRAN29.accretivehealth.local
# RAW ROWS: 7949
# FINAL ROWS: 7949
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN29.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN30.accretivehealth.local
# Connecting to TranJCIL @ ALPTRAN30.accretivehealth.local
# RAW ROWS: 4697
# FINAL ROWS: 4697
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN30.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN31.accretivehealth.local
# Connecting to TranBSTX @ ALPTRAN31.accretivehealth.local
# RAW ROWS: 569
# FINAL ROWS: 569
# Connecting to TranRHTX @ ALPTRAN31.accretivehealth.local
# RAW ROWS: 1066
# FINAL ROWS: 1066
# Connecting to TranCHWI @ ALPTRAN31.accretivehealth.local
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN31.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN33.accretivehealth.local
# Connecting to TranAAIL @ ALPTRAN33.accretivehealth.local
# RAW ROWS: 7508
# FINAL ROWS: 7508
# Connecting to TranHBIL @ ALPTRAN33.accretivehealth.local
# RAW ROWS: 185
# FINAL ROWS: 185
# Connecting to TranSAIL @ ALPTRAN33.accretivehealth.local
# RAW ROWS: 6687
# FINAL ROWS: 6687
# Connecting to TranNVIN @ ALPTRAN33.accretivehealth.local
# RAW ROWS: 986
# FINAL ROWS: 986
# Connecting to TranALIL @ ALPTRAN33.accretivehealth.local
# RAW ROWS: 1044
# FINAL ROWS: 1044
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN33.accretivehealth.local.xlsx
#
# Processing Server: ALPTRAN41.accretivehealth.local
# Connecting to TranSIFL @ ALPTRAN41.accretivehealth.local
# RAW ROWS: 509
# FINAL ROWS: 509
# Saved: C:\Users\IN10052060\Downloads\Data\Bad Debt New Code 1.txt_ALPTRAN41.accretivehealth.local.xlsx
# DONE

# %% [markdown]
# import os
# import sys
# import re
# import time
# import html
# import warnings
# from datetime import datetime
# from typing import List, Tuple, Optional
#
# import pandas as pd
# import pyodbc
# from openpyxl import Workbook, load_workbook
# from openpyxl.utils.dataframe import dataframe_to_rows
#
# try:
#     import winsound
# except ImportError:
#     winsound = None
#
# warnings.filterwarnings("ignore", category=UserWarning)
#
# # ----------------------------- #
# # --------- CONFIGURE --------- #
# # ----------------------------- #
#
# DB_STRUCTURE_PATH = r"C:\Users\IN10052060\Desktop\Python\SqlDBStructure.xlsx"
# EXCEL_SHEET_NAME = "AAIL"  # Columns: A=Facility, B=Database, C=Server
#
# SQL_FOLDER = r"C:\Users\IN10052060\Downloads\Query"
# OUTPUT_DIR = r"C:\Users\IN10052060\Downloads\Data"
#
# DEFAULT_TIMEOUT_SECONDS = 120   # Allow heavier batches to finish
# ENABLE_ODBC_ENCRYPTION = False  # Set True if your env requires encryption
#
# DB_PAUSE_SECONDS = 0.20         # Small pause between DBs to reduce tempdb races
#
# # Optional: set True to log duplicate column names encountered in result sets
# LOG_DUPLICATE_COLUMNS = False
#
# # ----------------------------- #
# # ---------- HELPERS ---------- #
# # ----------------------------- #
#
# def ensure_dir(path: str) -> None:
#     if not os.path.exists(path):
#         os.makedirs(path, exist_ok=True)
#
# def safe_strip(val) -> Optional[str]:
#     if val is None:
#         return None
#     if isinstance(val, str):
#         s = val.strip()
#         return s if s else None
#     return str(val).strip()
#
# def is_invalid_cell(text: Optional[str]) -> bool:
#     if text is None:
#         return True
#     t = text.strip()
#     if not t:
#         return True
#     if t.startswith("="):
#         return True
#     return False
#
# def read_db_targets_from_excel(xlsx_path: str, sheet_name: str) -> pd.DataFrame:
#     try:
#         wb = load_workbook(xlsx_path, data_only=True)
#     except Exception as e:
#         raise RuntimeError(f"Failed to open DB structure file: {xlsx_path}\n{e}")
#
#     if sheet_name not in wb.sheetnames:
#         raise ValueError(f"Sheet '{sheet_name}' not found in '{xlsx_path}'. Available: {wb.sheetnames}")
#
#     ws = wb[sheet_name]
#
#     targets: List[Tuple[Optional[str], str, str]] = []
#     bad_rows: List[Tuple[int, Optional[str], Optional[str], Optional[str]]] = []
#
#     # A=Facility, B=Database, C=Server
#     for r in range(2, ws.max_row + 1):
#         facility = safe_strip(ws.cell(row=r, column=1).value)
#         database = safe_strip(ws.cell(row=r, column=2).value)
#         server   = safe_strip(ws.cell(row=r, column=3).value)
#
#         if is_invalid_cell(server) or is_invalid_cell(database):
#             bad_rows.append((r, facility, database, server))
#             continue
#
#         targets.append((facility, database, server))
#
#     if bad_rows:
#         print("⚠️ Skipped rows with missing/formula values (row, facility, database, server):")
#         for item in bad_rows[:10]:
#             print("   ", item)
#         if len(bad_rows) > 10:
#             print(f"   ... and {len(bad_rows) - 10} more")
#
#     if not targets:
#         raise ValueError(
#             "No valid Server/Database rows found.\n"
#             "- Ensure formulas are evaluated (open & save in Excel with Ctrl+Alt+F9).\n"
#             "- Or replace formulas with static values."
#         )
#
#     df = pd.DataFrame(targets, columns=["Facility", "Database", "Server"])
#     df.drop_duplicates(inplace=True)
#     df = df.dropna(subset=["Database", "Server"])
#     return df
#
# def read_sql_file(path: str) -> str:
#     encodings = ["utf-8-sig", "utf-8", "cp1252", "latin-1"]
#     for enc in encodings:
#         try:
#             with open(path, "r", encoding=enc) as f:
#                 return f.read()
#         except UnicodeDecodeError:
#             continue
#     with open(path, "r", encoding="utf-8", errors="ignore") as f:
#         return f.read()
#
# def sanitize_query(sql_text: str) -> str:
#     """
#     - Removes standalone GO lines
#     - Unescapes HTML entities (&gt;,&lt;,&amp;)
#     - Converts named PK constraints on temp tables to unnamed PRIMARY KEY
#       to avoid SQL 2714 in tempdb across concurrent sessions.
#     - Injects SET NOCOUNT ON; and SET XACT_ABORT ON; at top if missing
#     """
#     # Remove 'GO' batch separators
#     lines = []
#     for line in sql_text.splitlines():
#         if line.strip().upper() == "GO":
#             continue
#         lines.append(line)
#     text = "\n".join(lines)
#
#     # Unescape HTML entities (&amp;gt; -> >, etc.)
#     text = html.unescape(text)
#
#     # Replace named temp-table PK constraints like:
#     #   CONSTRAINT PK_#act PRIMARY KEY ...
#     # or any constraint whose name contains '#'
#     # with an unnamed PRIMARY KEY
#     # Handles optional [brackets] and case-insensitive
#     text = re.sub(
#         r"CONSTRAINT\s+\[?(?:PK_)?[^ \]]*#\w+\]?\s+PRIMARY\s+KEY",
#         "PRIMARY KEY",
#         text,
#         flags=re.IGNORECASE
#     )
#
#     # Ensure SET NOCOUNT ON; is at top
#     header = text.lstrip()
#     if not header.upper().startswith("SET NOCOUNT ON;"):
#         text = "SET NOCOUNT ON;\n" + text
#
#     # Also add XACT_ABORT for cleaner failure behavior
#     header2 = text.lstrip()
#     if not header2.upper().startswith("SET XACT_ABORT ON;"):
#         text = "SET XACT_ABORT ON;\n" + text
#
#     return text
#
# def clean_illegal_characters(value):
#     if isinstance(value, str):
#         return "".join(ch for ch in value if ch.isprintable())
#     return value
#
# # ----------------------------- #
# #  MODIFIED: SAFER DF CLEANING  #
# # ----------------------------- #
#
# def _make_unique_columns(cols: List[object]) -> List[str]:
#     """
#     Coerce to strings, strip whitespace, and make names unique (A, A.1, A.2, ...).
#     """
#     str_cols = [str(c).strip() if c is not None else "" for c in cols]
#     seen = {}
#     unique_cols = []
#     for c in str_cols:
#         if c in seen:
#             seen[c] += 1
#             unique_cols.append(f"{c}.{seen[c]}")
#         else:
#             seen[c] = 0
#             unique_cols.append(c)
#     return unique_cols
#
# def log_duplicate_columns(cols: List[object]) -> None:
#     if not LOG_DUPLICATE_COLUMNS:
#         return
#     from collections import Counter
#     # stringified (stripped) view to reflect how they will be processed
#     str_cols = [str(c).strip() if c is not None else "" for c in cols]
#     counter = Counter(str_cols)
#     dups = [c for c, n in counter.items() if n > 1]
#     if dups:
#         print("ℹ️ Duplicate columns found and disambiguated:", ", ".join(dups))
#
# def clean_dataframe(df: pd.DataFrame) -> pd.DataFrame:
#     """
#     Defensive cleaner that avoids .dtype on DataFrame when duplicate column names exist.
#
#     - Coerces all column labels to strings and strips whitespace.
#     - Deduplicates column names by appending .1, .2, ... where needed.
#     - Cleans only object (string-like) columns.
#     - Drops duplicate rows.
#     """
#     if df is None or df.empty:
#         return df
#
#     df_cleaned = df.copy()
#
#     # Log duplicates (optional) and enforce unique column names
#     log_duplicate_columns(list(df_cleaned.columns))
#     df_cleaned.columns = _make_unique_columns(list(df_cleaned.columns))
#
#     # Clean only object dtype columns
#     obj_cols = df_cleaned.select_dtypes(include=["object"]).columns
#     for c in obj_cols:
#         df_cleaned[c] = df_cleaned[c].apply(clean_illegal_characters)
#
#     # Final tidy-ups
#     df_cleaned.columns = [col.strip() for col in df_cleaned.columns]
#     df_cleaned.drop_duplicates(inplace=True)
#
#     return df_cleaned
#
# def pick_best_odbc_driver() -> str:
#     try:
#         drivers = pyodbc.drivers()
#     except Exception:
#         drivers = []
#     for cand in ("ODBC Driver 18 for SQL Server", "ODBC Driver 17 for SQL Server", "SQL Server"):
#         if cand in drivers:
#             return cand
#     return "SQL Server"
#
# # ----------------------------- #
# #    CORE: ROBUST FETCH DATA    #
# # ----------------------------- #
#
# def fetch_data(
#     database: str,
#     server: str,
#     query: str,
#     timeout: int = DEFAULT_TIMEOUT_SECONDS,
#     encrypt: bool = ENABLE_ODBC_ENCRYPTION
# ) -> Tuple[Optional[pd.DataFrame], int, float, str]:
#     """
#     Execute an entire multi-statement batch in ONE call.
#     Advance through non-result sets until the first set with columns is found.
#     Build DataFrame manually—no pandas.read_sql_query (which expects a result set immediately).
#     """
#     start = datetime.now()
#     conn = None
#     try:
#         driver = pick_best_odbc_driver()
#         conn_str = (
#             f"Driver={{{driver}}};"
#             f"Server={server};"
#             f"Database={database};"
#             "Trusted_Connection=Yes;"
#             f"Timeout={timeout};"
#         )
#         if encrypt and ("ODBC Driver 17" in driver or "ODBC Driver 18" in driver):
#             conn_str += "Encrypt=Yes;TrustServerCertificate=Yes;"
#
#         print(f"Connecting to DB='{database}' on Server='{server}' using Driver='{driver}' ...")
#         conn = pyodbc.connect(conn_str, timeout=timeout, autocommit=True)
#         cur = conn.cursor()
#         # Optional: cursor-level timeout (some environments require this)
#         try:
#             cur.timeout = timeout
#         except Exception:
#             pass
#
#         # Execute entire script once (temp tables persist within this connection)
#         cur.execute(query)
#
#         # Walk through intermediate sets until we find the first result set with columns
#         columns = None
#         rows = None
#
#         while True:
#             if cur.description:
#                 columns = [c[0] for c in cur.description]
#                 rows = cur.fetchall()
#                 break
#             if not cur.nextset():
#                 break  # No more sets; no result set produced
#
#         duration = (datetime.now() - start).total_seconds()
#
#         # No result set -> return empty DataFrame but Success
#         if not columns:
#             return (pd.DataFrame(), 0, duration, "Success")
#
#         df = pd.DataFrame.from_records(rows, columns=columns)
#         # MOD: Clean with safe function that handles duplicate column names
#         df_cleaned = clean_dataframe(df)
#         return (df_cleaned, len(df_cleaned), duration, "Success")
#
#     except pyodbc.Error as e:
#         duration = (datetime.now() - start).total_seconds()
#         status = f"pyodbc.Error: {e}"
#         print(f"❌ {status}")
#         return (None, 0, duration, status)
#     except Exception as e:
#         duration = (datetime.now() - start).total_seconds()
#         status = f"Error: {type(e).__name__}: {e}"
#         print(f"❌ {status}")
#         return (None, 0, duration, status)
#     finally:
#         if conn is not None:
#             try:
#                 conn.close()
#             except Exception:
#                 pass
#
# def beep_success():
#     try:
#         if winsound:
#             winsound.MessageBeep()
#     except Exception:
#         pass
#
# # ----------------------------- #
# # ------------ MAIN ----------- #
# # ----------------------------- #
#
# def main():
#     # Validate inputs
#     if not os.path.exists(DB_STRUCTURE_PATH):
#         print(f"❌ DB_STRUCTURE_PATH not found: {DB_STRUCTURE_PATH}")
#         sys.exit(1)
#     if not os.path.exists(SQL_FOLDER):
#         print(f"❌ SQL_FOLDER not found: {SQL_FOLDER}")
#         sys.exit(1)
#     ensure_dir(OUTPUT_DIR)
#
#     # Load targets
#     print("📘 Loading DB targets from Excel (evaluated values)...")
#     df_targets = read_db_targets_from_excel(DB_STRUCTURE_PATH, EXCEL_SHEET_NAME)
#     if df_targets.empty:
#         print("❌ No valid targets after filtering.")
#         sys.exit(1)
#
#     servers_grouped = df_targets.groupby("Server", dropna=True)
#
#     # Collect SQL files
#     sql_files = [f for f in os.listdir(SQL_FOLDER) if f.lower().endswith((".sql", ".txt"))]
#     if not sql_files:
#         print(f"❌ No .sql or .txt files found in: {SQL_FOLDER}")
#         sys.exit(1)
#
#     # Process each SQL file
#     for sql_file in sql_files:
#         sql_path = os.path.join(SQL_FOLDER, sql_file)
#         print(f"\n🔍 Running query from: {sql_file}")
#
#         raw_query = read_sql_file(sql_path)
#         query = sanitize_query(raw_query)
#
#         # --- Overall counters across all servers for this SQL file ---
#         overall_total = 0
#         overall_succeeded = 0
#         overall_failed = 0
#         overall_failed_list: List[str] = []  # e.g., "TranMTTN@AHS-TRAN15.accretivehealth.local"
#
#         for server, group in servers_grouped:
#             print(f"\n➡️ Processing Server: {server}")
#
#             # Prepare Excel workbook for this server
#             master_file = Workbook()
#             log_sheet = master_file.active
#             log_sheet.title = "Log"
#             raw_data_sheet = master_file.create_sheet("RawData")
#             summary_sheet = master_file.create_sheet("Summary")
#
#             log_sheet.append(["Server", "Database", "Status", "Row Count", "Duration (s)", "Timestamp"])
#             summary_sheet.append(["Server", "Total Databases", "Succeeded", "Failed", "Failed DB Names"])
#
#             dfs: List[pd.DataFrame] = []
#             header_written = False
#
#             # Per-server stats
#             total_dbs = 0
#             succeeded = 0
#             failed = 0
#             failed_db_names: List[str] = []
#
#             # Loop through databases for this server
#             for _, row in group.iterrows():
#                 database = row["Database"]
#                 total_dbs += 1
#                 overall_total += 1  # overall attempt
#
#                 start_time = datetime.now()
#
#                 df, row_count, duration, status = fetch_data(
#                     database=database,
#                     server=server,
#                     query=query,
#                     timeout=DEFAULT_TIMEOUT_SECONDS,
#                     encrypt=ENABLE_ODBC_ENCRYPTION
#                 )
#
#                 # Log per-database result
#                 log_sheet.append([
#                     server,
#                     database,
#                     status,
#                     row_count,
#                     round(duration, 2),
#                     start_time.strftime("%Y-%m-%d %H:%M:%S")
#                 ])
#
#                 # Tally
#                 if status == "Success":
#                     succeeded += 1
#                     overall_succeeded += 1
#                     if df is not None and not df.empty:
#                         if not header_written:
#                             for r in dataframe_to_rows(df, index=False, header=True):
#                                 raw_data_sheet.append(r)
#                             header_written = True
#                         else:
#                             for r in dataframe_to_rows(df, index=False, header=False):
#                                 raw_data_sheet.append(r)
#                         dfs.append(df)
#                 else:
#                     failed += 1
#                     overall_failed += 1
#                     failed_db_names.append(str(database))
#                     overall_failed_list.append(f"{database}@{server}")
#
#                 # Small pause to reduce tempdb constraint races
#                 if DB_PAUSE_SECONDS > 0:
#                     time.sleep(DB_PAUSE_SECONDS)
#
#             # Add per-server summary row
#             summary_sheet.append([
#                 server,
#                 total_dbs,
#                 succeeded,
#                 failed,
#                 ", ".join(failed_db_names) if failed_db_names else ""
#             ])
#
#             # Console summary for the server
#             if failed > 0:
#                 print(f"⚠️ Server '{server}': {succeeded}/{total_dbs} databases succeeded.")
#                 print(f"   Failed: {', '.join(failed_db_names)}")
#             else:
#                 print(f"✅ Server '{server}': All {total_dbs} databases succeeded.")
#
#             # Save result for this server
#             timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
#             base_name = os.path.splitext(sql_file)[0]
#             safe_server = server.replace("\\", "_").replace("/", "_").replace(":", "_")
#             output_file = os.path.join(OUTPUT_DIR, f"{base_name}_{safe_server}_{timestamp}.xlsx")
#
#             master_file.save(output_file)
#
#             # Combined shape info (best-effort)
#             combined_shape = (0, 0)
#             if dfs:
#                 try:
#                     combined_shape = pd.concat(dfs, ignore_index=True).shape
#                 except Exception:
#                     combined_shape = (sum(len(d) for d in dfs), len(dfs[0].columns))
#
#             print(f"✅ Saved result for Server {server}: {output_file}")
#             print(f"📊 Combined shape for {server}: {combined_shape}\n")
#
#         # --- Overall summary for this SQL file ---
#         print(f"🧮 Overall for {sql_file}: {overall_succeeded}/{overall_total} databases succeeded; {overall_failed} failed")
#         if overall_failed_list:
#             print("   ❌ Failed DBs: " + ", ".join(overall_failed_list))
#         print("")  # spacer
#
#     beep_success()
#     print("🎉 All done.")
#
# if __name__ == "__main__":
#     main()

# %%
import os
import pandas as pd

# --- CONFIGURATION ---
EXCEL_FOLDER = r"C:\Users\IN10052060\Downloads\Data" # Update to your folder path
combined_df = pd.DataFrame()

# --- LOOP THROUGH EXCEL FILES ---
excel_files = [f for f in os.listdir(EXCEL_FOLDER) if f.endswith(".xlsx")]

print(f"Found {len(excel_files)} Excel files:")
for file in excel_files:
    file_path = os.path.join(EXCEL_FOLDER, file)
    try:
        # Read the 'RawData' sheet (adjust if needed)
        df = pd.read_excel(file_path, sheet_name="Data")
        df["SourceFile"] = file  # Optional: track origin
        combined_df = pd.concat([combined_df, df], ignore_index=True)
        print(f"✅ Loaded: {file} ({df.shape[0]} rows)")
    except Exception as e:
        print(f"❌ Error loading {file}: {e}")

# --- PREVIEW RESULT ---
print(f"\n📊 Combined shape: {combined_df.shape}")
print(combined_df.head())

# %%
combined_df.shape

# %%
combined_df.to_excel(os.path.join(EXCEL_FOLDER, "Combined_Output.xlsx"), index=False)

# %% [markdown]
# import win32com.client as win32
# import os
#
# # Folder path
# folder_path = r"C:\Users\IN10052060\Downloads\Data"
#
# # Specific file name you want to send
# file_name = "Combined_Output.xlsx"   # <-- change this
#
# # Build full file path
# output_file = os.path.join(folder_path, file_name)
#
# # Validate file exists
# if not os.path.exists(output_file):
#     raise FileNotFoundError(f"File not found: {output_file}")
#
# # Outlook automation
# outlook = win32.Dispatch('outlook.application')
# mail = outlook.CreateItem(0)
#
# mail.To = "ARai1@R1RCM.COM"
# mail.Subject = "ARMT 2B Part 7- Bad Debt and pt payment not equal 0"
# mail.Body = (
#     "Hi Team,\n\n"
#     "Please find attached the report.\n\n"
#     "Regards,\n"
#     "Karan"
# )
#
# mail.Attachments.Add(output_file)
# mail.Send()
#
# print(f"Email sent successfully with attachment: {output_file}")
